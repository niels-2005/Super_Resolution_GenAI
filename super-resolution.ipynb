# %%
# import helper function

from helper import upscale_image
# Out:
# 2024-04-10 13:50:47.825612: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-10 13:50:47.850306: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-10 13:50:47.850326: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-10 13:50:47.850921: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# get image

# !wget "https://user-images.githubusercontent.com/12981474/40157448-eff91f06-5953-11e8-9a37-f6b5693fa03f.png" -O original.png
# Out:
# --2024-04-10 13:46:55--  https://user-images.githubusercontent.com/12981474/40157448-eff91f06-5953-11e8-9a37-f6b5693fa03f.png
# Resolving user-images.githubusercontent.com (user-images.githubusercontent.com)... 2606:50c0:8001::154, 2606:50c0:8000::154, 2606:50c0:8003::154, ...
# Connecting to user-images.githubusercontent.com (user-images.githubusercontent.com)|2606:50c0:8001::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34146 (33K) [image/png]
# Saving to: ‘original.png’
#
# original.png        100%[===================>]  33,35K  --.-KB/s    in 0,006s
#
# 2024-04-10 13:46:56 (5,85 MB/s) - ‘original.png’ saved [34146/34146]

# %%
# get img

# !wget "https://lh4.googleusercontent.com/-Anmw5df4gj0/AAAAAAAAAAI/AAAAAAAAAAc/6HxU8XFLnQE/photo.jpg64" -O test.jpg
# Out:
# --2024-04-10 13:47:10--  https://lh4.googleusercontent.com/-Anmw5df4gj0/AAAAAAAAAAI/AAAAAAAAAAc/6HxU8XFLnQE/photo.jpg64
# Resolving lh4.googleusercontent.com (lh4.googleusercontent.com)... 2a00:1450:4001:82f::2001, 142.250.181.225
# Connecting to lh4.googleusercontent.com (lh4.googleusercontent.com)|2a00:1450:4001:82f::2001|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84897 (83K) [image/jpeg]
# Saving to: ‘test.jpg’
#
# test.jpg            100%[===================>]  82,91K  --.-KB/s    in 0,05s
#
# 2024-04-10 13:47:10 (1,65 MB/s) - ‘test.jpg’ saved [84897/84897]

# %%
# image paths

ANIMAL_LOW_RES = "original.png"
SNOW_ANIMAL_LOW_RES = "test.jpg"

# %%
# short documentation about helper function

upscale_image?
# Out:
# Signature:
# upscale_image(
#     image_path: str,
#     display_original_img: bool = True,
#     model_hub_path: str = 'https://tfhub.dev/captain-pool/esrgan-tf2/1',
#     save_image: bool = False,
#     save_img_filename: str = 'hr_image',
# ) -> tensorflow.python.framework.tensor.Tensor
# Docstring:
# Performs image super-resolution on a given image using a pre-trained ESRGAN model from TensorFlow Hub. Optionally,
# displays the original and super-resolved images, and can save the high-resolution image to disk.
#
# Args:
#     image_path (str): The file path to the image to be upscaled.
#     display_original_img (bool, optional): If True, the original image will be displayed. Defaults to True.
#     model_hub_path (str, optional): The URL to the TensorFlow Hub model to be used for super-resolution.
#         Defaults to "https://tfhub.dev/captain-pool/esrgan-tf2/1".
#     save_image (bool, optional): If True, the super-resolved image will be saved to disk. Defaults to False.
# ...

# %%
# Super Resolution on Test Image

upscale_image(image_path=ANIMAL_LOW_RES)
# Out:
# 2024-04-10 13:50:22.174095: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-10 13:50:22.194813: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...

# %%
# Super Resolution on Test Image and directly saving

upscale_image(image_path=SNOW_ANIMAL_LOW_RES, save_image=True, save_img_filename="upscaled_img.jpg")
# Out:
# 2024-04-10 13:51:39.497531: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-10 13:51:39.520007: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...

# %%
import matplotlib.pyplot as plt

SNOW_ANIMAL_HIGHER_RES = "upscaled_img.jpg"

# %%
img = plt.imread(SNOW_ANIMAL_HIGHER_RES) / 255.
plt.imshow(img)
plt.axis("off")
plt.show()
